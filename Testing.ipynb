# %%
import pandas as pd

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    URL_ID                                                URL  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
#
#                                        CleanedCorpus  \
# 0   introduction   if kill 10 million people deca...
# 1   human mind   fascination carrying potential t...
# 2   introduction rapidly evolving employment sect...
# 3     anything give rise smarter than human intel...
# 4     machine intelligence invention humanity mak...
#
#                                            RawCorpus  PositiveScore  \
# 0   introduction “ if anything kills over 10 mill...             80
# 1   human minds , a fascination in itself carryin...             76
# 2   introduction ai is rapidly evolving in the em...             68
# 3   “ anything that could give rise to smarter-th...             67
# 4   “ machine intelligence is the last invention ...             65
#
#    NegativeScore  PolarityScore  SubjectivityScore  RawSenCount  RawWordCount  \
# 0             37       0.367521           0.213894           77          1993
# 1             38       0.333333           0.208410           79          1630
# 2             42       0.236364           0.201097           84          1899
# 3             31       0.367347           0.179159           92          1765
# 4             27       0.413043           0.168190           82          1930
#
#    avgSenLen  complexCount  Fog Index  cleanWordCount  syllables  \
# 0  25.883117            65  11.657813            1064       2704
# 1  20.632911            50   9.480158             660       1477
# 2  22.607143            64  10.390935             917       2355
# 3  19.184783            65   9.147001             729       1708
# 4  23.536585            65  10.761784             892       2054
#
#    PersonalPronouns  charCount  AvgWordLen
# 0                 1       3600    1.806322
# 1                 7       3600    2.208589
# 2                 3       3600    1.895735
# 3                18       3600    2.039660
# 4                16       3600    1.865285

# %%
data['POSITIVE SCORE']=df['PositiveScore']
data['NEGATIVE SCORE']=df['NegativeScore']
data['POLARITY SCORE']=df['PolarityScore']
data['SUBJECTIVITY SCORE']=df['SubjectivityScore']
data['AVG SENTENCE LENGTH']=df['avgSenLen'] ## I feel this was supposed to be in character length, but followed the assignment's instructions
data['PERCENTAGE OF COMPLEX WORDS']=100*df['complexCount']/df['RawWordCount']
data['FOG INDEX']=df['Fog Index']
data['AVG NUMBER OF WORDS PER SENTENCE']=df['avgSenLen']
data['COMPLEX WORD COUNT']=df['complexCount']
data['WORD COUNT']=df['cleanWordCount']
data['SYLLABLE PER WORD']=df['syllables']/df['RawWordCount']
data['PERSONAL PRONOUNS']=df['PersonalPronouns']
data['AVG WORD LENGTH']=df['AvgWordLen']

# %%
data.columns
# Out:
# Index(['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
#        'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],
#       dtype='object')

# %%
import numpy as np

# %%
df.isin([np.inf, -np.inf]).sum()
# Out:
# URL_ID               0
# URL                  0
# CleanedCorpus        0
# RawCorpus            0
# PositiveScore        0
# NegativeScore        0
# PolarityScore        0
# SubjectivityScore    0
# RawSenCount          0
# RawWordCount         0
# avgSenLen            0
# complexCount         0
# Fog Index            0
# cleanWordCount       0
# syllables            0
# PersonalPronouns     0
# charCount            0
# AvgWordLen           3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# URL_ID               0
# URL                  0
# CleanedCorpus        0
# RawCorpus            0
# PositiveScore        0
# NegativeScore        0
# PolarityScore        0
# SubjectivityScore    0
# RawSenCount          0
# RawWordCount         0
# avgSenLen            0
# complexCount         0
# Fog Index            3
# cleanWordCount       0
# syllables            0
# PersonalPronouns     0
# charCount            0
# AvgWordLen           0
# dtype: int64

# %%
df.head(10)
# Out:
#    URL_ID                                                URL  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
# 5      42  https://insights.blackcoffer.com/man-and-machi...
# 6      43  https://insights.blackcoffer.com/in-future-or-...
# 7      44  https://insights.blackcoffer.com/how-neural-ne...
# 8      45  https://insights.blackcoffer.com/how-machine-l...
# 9      46  https://insights.blackcoffer.com/deep-learning...
#
#                                        CleanedCorpus  \
# 0   introduction   if kill 10 million people deca...
# 1   human mind   fascination carrying potential t...
# 2   introduction rapidly evolving employment sect...
# 3     anything give rise smarter than human intel...
# 4     machine intelligence invention humanity mak...
# 5   where disruptive technology taking   take lea...
# 6   in future upcoming year human machine work fi...
# 7
# 8   machine learning technique year   recently ex...
# 9   elearning technology affordable higher educat...
#
#                                            RawCorpus  PositiveScore  \
# 0   introduction “ if anything kills over 10 mill...             80
# 1   human minds , a fascination in itself carryin...             76
# 2   introduction ai is rapidly evolving in the em...             68
# 3   “ anything that could give rise to smarter-th...             67
# 4   “ machine intelligence is the last invention ...             65
# 5   where is this disruptive technology taking us...             45
# 6   in future or in upcoming years humans and mac...             20
# 7                                                                 0
# 8   machine learning techniques may have been use...             38
# 9   elearning as technology becomes more affordab...             75
#
#    NegativeScore  PolarityScore  SubjectivityScore  RawSenCount  RawWordCount  \
# 0             37       0.367521           0.213894           77          1993
# 1             38       0.333333           0.208410           79          1630
# 2             42       0.236364           0.201097           84          1899
# 3             31       0.367347           0.179159           92          1765
# 4             27       0.413043           0.168190           82          1930
# 5             25       0.285714           0.127971           49          1229
# 6              7       0.481481           0.049360           37           635
# 7              0       0.000000           0.000000            0             0
# 8             14       0.461538           0.095064           35           791
# 9             45       0.250000           0.219378           79          2405
#
#    avgSenLen  complexCount  Fog Index  cleanWordCount  syllables  \
# 0  25.883117            65  11.657813            1064       2704
# 1  20.632911            50   9.480158             660       1477
# 2  22.607143            64  10.390935             917       2355
# 3  19.184783            65   9.147001             729       1708
# 4  23.536585            65  10.761784             892       2054
# 5  25.081633            26  10.878869             539       1249
# 6  17.162162             6   7.242818             281        640
# 7   0.000000             0        NaN               0          0
# 8  22.600000            11   9.596258             363        760
# 9  30.443038            71  13.358088            1047       2464
#
#    PersonalPronouns  charCount  AvgWordLen
# 0                 1       3600    1.806322
# 1                 7       3600    2.208589
# 2                 3       3600    1.895735
# 3                18       3600    2.039660
# 4                16       3600    1.865285
# 5                12       3600    2.929211
# 6                 4       3600    5.669291
# 7                 0       3600         inf
# 8                 2       3600    4.551201
# 9                11       3600    1.496881

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                80              37        0.367521            0.213894
# 1                76              38        0.333333            0.208410
# 2                68              42        0.236364            0.201097
# 3                67              31        0.367347            0.179159
# 4                65              27        0.413043            0.168190
# ..              ...             ...             ...                 ...
# 109              23              28       -0.098039            0.093236
# 110              36              15        0.411765            0.093236
# 111              39              50       -0.123596            0.162706
# 112              37               6        0.720930            0.078611
# 113              44              45       -0.011236            0.162706
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0              25.883117                     3.261415  11.657813
# 1              20.632911                     3.067485   9.480158
# 2              22.607143                     3.370195  10.390935
# 3              19.184783                     3.682720   9.147001
# 4              23.536585                     3.367876  10.761784
# ..                   ...                          ...        ...
# 109            20.416667                     3.469388   9.554422
# 110            25.437500                     2.620803  11.223321
# 111            19.307692                     1.912351   8.488017
# 112            24.640000                     2.597403  10.894961
# 113            17.400000                     2.740937   8.056375
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                           25.883117                  65        1064
# 1                           20.632911                  50         660
# 2                           22.607143                  64         917
# 3                           19.184783                  65         729
# 4                           23.536585                  65         892
# ..                                ...                 ...         ...
# 109                         20.416667                  34         515
# 110                         25.437500                  32         630
# 111                         19.307692                  24         646
# 112                         24.640000                  16         298
# 113                         17.400000                  31         547
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0             1.356749                  1         1.806322
# 1             0.906135                  7         2.208589
# 2             1.240126                  3         1.895735
# 3             0.967705                 18         2.039660
# 4             1.064249                 16         1.865285
# ..                 ...                ...              ...
# 109           1.152041                  9         3.673469
# 110           1.181818                  2         2.948403
# 111           1.211952                  2         2.868526
# 112           1.285714                  0         5.844156
# 113           1.151194                  8         3.183024
#
# [114 rows x 15 columns]

# %%
data=pd.read_excel('Output Data Structure.xlsx')
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0               NaN             NaN             NaN                 NaN
# 1               NaN             NaN             NaN                 NaN
# 2               NaN             NaN             NaN                 NaN
# 3               NaN             NaN             NaN                 NaN
# 4               NaN             NaN             NaN                 NaN
# ..              ...             ...             ...                 ...
# 109             NaN             NaN             NaN                 NaN
# 110             NaN             NaN             NaN                 NaN
# 111             NaN             NaN             NaN                 NaN
# 112             NaN             NaN             NaN                 NaN
# 113             NaN             NaN             NaN                 NaN
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                    NaN                          NaN        NaN
# 1                    NaN                          NaN        NaN
# 2                    NaN                          NaN        NaN
# 3                    NaN                          NaN        NaN
# 4                    NaN                          NaN        NaN
# ..                   ...                          ...        ...
# 109                  NaN                          NaN        NaN
# 110                  NaN                          NaN        NaN
# 111                  NaN                          NaN        NaN
# 112                  NaN                          NaN        NaN
# 113                  NaN                          NaN        NaN
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                                 NaN                 NaN         NaN
# 1                                 NaN                 NaN         NaN
# 2                                 NaN                 NaN         NaN
# 3                                 NaN                 NaN         NaN
# 4                                 NaN                 NaN         NaN
# ..                                ...                 ...         ...
# 109                               NaN                 NaN         NaN
# 110                               NaN                 NaN         NaN
# 111                               NaN                 NaN         NaN
# 112                               NaN                 NaN         NaN
# 113                               NaN                 NaN         NaN
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                  NaN                NaN              NaN
# 1                  NaN                NaN              NaN
# 2                  NaN                NaN              NaN
# 3                  NaN                NaN              NaN
# 4                  NaN                NaN              NaN
# ..                 ...                ...              ...
# 109                NaN                NaN              NaN
# 110                NaN                NaN              NaN
# 111                NaN                NaN              NaN
# 112                NaN                NaN              NaN
# 113                NaN                NaN              NaN
#
# [114 rows x 15 columns]
